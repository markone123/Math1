# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0,10,300)
k=1
plt.plot(x,np.cos(x*k))
k=1.5
plt.plot(x,np.cos(x*k))
plt.xlabel('Значение X')
plt.ylabel('Значение Y')
plt.text(5.75,0.7,'k = 1')
plt.text(5.75,-0.7,'k = 1.5')
#print(x)
# Out:
# Text(5.75, -0.7, 'k = 1.5')
